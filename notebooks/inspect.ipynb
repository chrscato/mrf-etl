# %%
import pandas as pd

prov = pd.read_parquet(r"C:\Users\ChristopherCato\OneDrive - clarity-dx.com\code\bph\uhc_tic\output\providers_20250806_181227.parquet")

# %%
prov.columns
# Out:
# Index(['provider_group_id', 'npi', 'tin_type', 'tin_value',
#        'reporting_entity_name', 'reporting_entity_type', 'last_updated_on',
#        'version'],
#       dtype='object')

# %%
display(prov.head())
# Out:
#    provider_group_id         npi tin_type  tin_value  \
# 0                  0  1114725033      ein  741109665
# 1                  0  1194787218      ein  741109665
# 2                  0  1447883301      ein  741109665
# 3                 11  1386213460      ein  854240994
# 4                 16  1598297269      ein  811896540
#
#                reporting_entity_name reporting_entity_type last_updated_on  \
# 0  UnitedHealthcare of Georgia, Inc.               Insurer      2025-08-01
# 1  UnitedHealthcare of Georgia, Inc.               Insurer      2025-08-01
# 2  UnitedHealthcare of Georgia, Inc.               Insurer      2025-08-01
# 3  UnitedHealthcare of Georgia, Inc.               Insurer      2025-08-01
# 4  UnitedHealthcare of Georgia, Inc.               Insurer      2025-08-01
#
#   version
# 0   1.0.0
# 1   1.0.0
# 2   1.0.0
# 3   1.0.0
# 4   1.0.0

# %%
print(f"unique provider_group_id: {prov['provider_group_id'].unique()}")
# Out:
# unique provider_group_id: [    0    11    16 ... 40405 40419 40432]

# %%
rates = pd.read_parquet(r"C:\Users\ChristopherCato\OneDrive - clarity-dx.com\code\bph\uhc_tic\output\rates_20250806_215825.parquet")
rates.columns
display(rates.head())
print(f"unique provider_reference_id: {rates['provider_reference_id'].unique()}")
# Out:
#    provider_reference_id  negotiated_rate negotiated_type  billing_class  \
# 0                    640              0.0      negotiated  institutional
# 1                    640              0.0      negotiated  institutional
# 2                    640              0.0      negotiated  institutional
# 3                    640              0.0      negotiated  institutional
# 4                    640              0.0      negotiated  institutional
#
#   expiration_date    service_codes billing_code billing_code_type  \
# 0      9999-12-31  ['n', 'u', 'l']        70030               CPT
# 1      9999-12-31  ['n', 'u', 'l']        70030               CPT
# 2      9999-12-31  ['n', 'u', 'l']        70030               CPT
# 3      9999-12-31  ['n', 'u', 'l']        70030               CPT
# 4      9999-12-31  ['n', 'u', 'l']        70030               CPT
#
#                                          description  \
# 0  Radiologic examination, eye, for detection of ...
# ...
