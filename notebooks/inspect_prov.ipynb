# %%
import pandas as pd


prov = pd.read_parquet(r"C:\Users\ChristopherCato\OneDrive - clarity-dx.com\code\bph\mrf-etl\data\output\processed_uhc_providers.parquet")

# %%
prov.columns
# Out:
# Index(['provider_group_id', 'prov_npi', 'tin_type', 'tin_value',
#        'reporting_entity_name', 'reporting_entity_type', 'last_updated_on',
#        'version', 'enumeration_type', 'org_name', 'status',
#        'primary_taxonomy_code', 'primary_taxonomy_desc', 'address_purpose',
#        'address_type', 'address_1', 'address_2', 'city', 'state',
#        'postal_code', 'country_code', 'telephone_number', 'fax_number',
#        'error'],
#       dtype='object')

# %%
print(f"number of unique tin_value: {prov['tin_value'].nunique()}")
# Out:
# number of unique tin_value: 7089

# %%
# Filter for NPI-2 and NPI-1 enumerations
npi2 = prov[prov['enumeration_type'] == 'NPI-2']
npi1 = prov[prov['enumeration_type'] == 'NPI-1']

# Group by TIN and get count of unique NPI-2s, NPI-1s, and their org_names
tin_summary = (
    prov.groupby('tin_value')
        .agg(
            npi2_count=('prov_npi', lambda x: x[prov.loc[x.index, 'enumeration_type'] == 'NPI-2'].nunique()),
            npi1_count=('prov_npi', lambda x: x[prov.loc[x.index, 'enumeration_type'] == 'NPI-1'].nunique()),
            org_names=('org_name', lambda x: list(pd.unique(x.dropna())))
        )
        .reset_index()
        .sort_values('npi2_count', ascending=False)
)

display(tin_summary.head(20))
# Out:
#       tin_value  npi2_count  npi1_count  \
# 70    042832065          22           0
# 6978  953372911          19           0
# 3585  582074947          13           0
# 3449  581928192           9           0
# 3937  582388975           8           0
# 4449  621323090           7           0
# 3474  581954432           7           2
# 4032  582461588           6           0
# 6977  952977916           3           0
# 3700  582179986           3           2
# 2996  580866776           3           0
# 2607  472221436           3          49
# 4142  582536074           2           3
# 4388  586001384           2           0
# 802   204176815           2           0
# 5554  841708057           2           2
# 4394  586002659           2           6
# 3978  582422542           2          33
# 3790  582257925           2           3
# 5242  825415284           2          19
#
#                                               org_names
# 70          [BIO-MEDICAL APPLICATIONS OF GEORGIA, INC.]
# 6978                             [TOTAL RENAL CARE INC]
# 3585  [PRUITTHEALTH HOSPICE, INC., PRUITTHEALTH HOSP...
# 3449  [PRUITTHEALTH HOME HEALTH - SOUTH ATLANTA, INC...
# 3937  [AMERICAN HEALTH IMAGING OF GEORGIA LLC, AMERI...
# 4449  [DVA RENAL HEALTHCARE INC, DVA RENAL HEALTHCAR...
# 3474                         [NORTHSIDE HOSPITAL, INC.]
# 4032                   [PRUITTHEALTH HOME HEALTH, INC.]
# 6977                    [DVA HEALTHCARE RENAL CARE INC]
# 3700  [PIEDMONT ATHENS REGIONAL MEDICAL CENTER, INC....
# 2996  [HOSPITAL AUTHORITY OF COLUMBUS, GA, HOSPITAL ...
# 2607  [WOODSTOCK PEDIATRICS PC, JORGE AMADOR MD LLC,...
# 4142  [THE LIGHTHOUSE COUNSELING CLINIC, INC., LIGHT...
# 4388                   [LIBERTY COUNTY BOARD OF HEALTH]
# 802   [MESUN HEALTH SERVICES INC, MESUN HEALTH SERVI...
# 5554  [ATLANTA ONCOLOGY ASSOCIATES, PC, NORTHSIDE HO...
# 4394  [THE BAXLEY AND APPLING COUNTY HOSPITAL AUTHOR...
# 3978  [OBSTETRICS & GYNECOLOGY OF ATLANTA II LLC, PE...
# 3790  [EVANS MEMORIAL HOSPITAL, EVANS MEMORIAL HOSPI...
# 5242  [NORTHEAST GEORGIA DIAGNOSTIC ASSOCIATES AND C...

# %%
with pd.option_context('display.max_columns', None):
    print(prov[prov['tin_value'] == '200235522'])
# Out:
#    provider_group_id    prov_npi tin_type  tin_value  \
# 1                  1  1104897024      ein  200235522
#
#               reporting_entity_name reporting_entity_type last_updated_on  \
# 1  UnitedHealthcare of Georgia Inc.               Insurer      2025-08-01
#
#   version enumeration_type org_name status primary_taxonomy_code  \
# 1   1.0.0            NPI-1     None      A            207RG0100X
#
#                  primary_taxonomy_desc address_purpose address_type  \
# 1  Internal Medicine, Gastroenterology        LOCATION          DOM
#
#             address_1 address_2        city state postal_code country_code  \
# 1  1151 CLEVELAND AVE   SUITE D  EAST POINT    GA   303443600           US
#
#   telephone_number    fax_number error
# 1     404-761-7949  404-761-7386  None

# %%
unique_taxonomy = pd.Series(prov['primary_taxonomy_desc'].unique(), name='primary_taxonomy_desc')
unique_taxonomy.to_csv('unique_taxonomy.csv', index=False)

# %%
len(prov)
# Out:
# 14111

# %%
# keep needed taxonomies

import re

def keep_for_surg_rad(desc: str) -> bool:
    if not desc:
        return False
    d = str(desc).upper()

    # 1) Explicit facility keepers
    facility_keep = (
        "GENERAL ACUTE CARE HOSPITAL" in d or
        "GENERAL ACUTE CARE HOSPITAL, CRITICAL ACCESS" in d or
        "AMBULATORY SURGICAL" in d or  # catches "Clinic/Center, Ambulatory Surgical"
        "AMBULATORY SURGICAL CENTER" in d
    )
    if facility_keep:
        return True

    # 2) Simple keyword pass (tighten 'rad' to 'radiolog'/'radiation' to avoid false positives)
    simple_keywords = (
        "SURG",
        "HOSPITAL",
        "AMBULATORY"          # surgery, surgical, surgeon
        "RADIOLOG",       # radiology, radiologist
        "RADIATION",      # radiation oncology (keep if you want it)
        "IMAGING",        # imaging center, diagnostic imaging
        "IMAGE",          # catches "imagin" / typos; okay if you want it very broad
        "MULTI-SPECIALTY",
        "MULTISPECIALTY"
    )
    return any(k in d for k in simple_keywords)

# %%
# Example usage on a DataFrame `df` with 'primary_taxonomy_dest
taxonomy_prov = prov['primary_taxonomy_desc'].fillna("").map(keep_for_surg_rad)
kept_df   = prov[taxonomy_prov].copy()
dropped_df= prov[taxonomy_prov].copy()

# %%
len(kept_df)
# Out:
# 885

# %%
print(f"unique taxonomies: {kept_df['primary_taxonomy_desc'].nunique()}")
print(f"unique org_names: {kept_df['org_name'].nunique()}")

print(f"unique taxonomies: {kept_df['primary_taxonomy_desc'].unique()}")
print(f"unique org_names: {kept_df['org_name'].unique()}")
# Out:
# unique taxonomies: 50
# unique org_names: 234
# unique taxonomies: ['General Acute Care Hospital'
#  'Clinic/Center, Magnetic Resonance Imaging (MRI)'
#  'Clinic/Center, Oncology, Radiation' 'Physician Assistant, Surgical'
#  'Clinic/Center, Ambulatory Surgical'
#  'General Acute Care Hospital, Critical Access' 'Plastic Surgery'
#  'Hospitalist' 'Clinic/Center, Multi-Specialty'
#  'Dentist, Oral and Maxillofacial Surgery' 'Psychiatric Hospital'
#  'Long Term Care Hospital' 'Surgery' 'Podiatrist, Foot & Ankle Surgery'
#  'Dermatology, MOHS-Micrographic Surgery' 'Surgery, Pediatric Surgery'
#  'Orthopaedic Surgery' 'Orthopaedic Surgery, Sports Medicine'
#  'Colon & Rectal Surgery' 'Surgery, Plastic and Reconstructive Surgery'
#  'Orthopaedic Surgery, Hand Surgery' 'Surgery, Surgical Oncology'
#  'Obstetrics & Gynecology, Urogynecology and Reconstructive Pelvic Surgery'
#  'Thoracic Surgery (Cardiothoracic Vascular Surgery)'
#  'Ophthalmology, Ophthalmic Plastic and Reconstructive Surgery'
#  'Neurological Surgery'
#  'Orthopaedic Surgery, Orthopaedic Surgery of the Spine'
#  'Transplant Surgery'
#  'Otolaryngology, Otolaryngology/Facial Plastic Surgery'
#  'Orthopaedic Surgery, Adult Reconstructive Orthopaedic Surgery'
#  'Orthopaedic Surgery, Foot and Ankle Surgery'
#  'Clinic/Center, Ophthalmologic Surgery'
#  'Plastic Surgery, Surgery of the Hand'
#  'Radiologic Technologist, Magnetic Resonance Imaging'
#  'Radiology, Body Imaging'
#  'Specialist/Technologist, Other, Surgical Assistant' 'Special Hospital'
#  'Surgery, Surgery of the Hand' 'Orthopaedic Surgery, Orthopaedic Trauma'
#  'Surgery, Surgical Critical Care' 'Rehabilitation Hospital'
#  'Otolaryngology, Facial Plastic Surgery' 'Oral & Maxillofacial Surgery'
#  'Plastic Surgery, Plastic Surgery Within the Head and Neck'
#  'Surgery, Trauma Surgery' 'General Acute Care Hospital, Rural'
#  'General Acute Care Hospital, Children'
#  'Urology, Urogynecology and Reconstructive Pelvic Surgery'
#  'Orthopaedic Surgery, Pediatric Orthopaedic Surgery'
#  'Otolaryngology, Plastic Surgery within the Head & Neck']
# unique org_names: ['PIEDMONT NEWNAN HOSPITAL, INC.' 'JAMES ZIMMERMAN MD'
#  'SOUTH GEORGIA CENTER FOR CANCER CARE, LLC' None
#  'NORTHSIDE HOSPITAL, INC.' 'TATTNALL HOSPITAL COMPANY, LLC'
#  'EAST WEST SURGERY CENTER LP' 'HOSPITAL AUTHORITY OF WILKES COUNTY'
#  'BRASELTON ENDOSCOPY CENTER, LLC'
#  'GEORGIA SURGICAL CENTER ON PEACHTREE, LLC'
#  'SOUTHERN CRESCENT PLASTIC SURGERY ASC'
#  'HOSPITAL AUTHORITY OF LIBERTY COUNTY' 'AICA ORTHOPEDICS, P.C.'
#  'PIEDMONT ATHENS REGIONAL MEDICAL CENTER, INC.' 'SEDZER HEALTH LLC'
#  'SHEPHERD CENTER INC' 'GEORGIA PHLEBOLOGY PC'
#  'UNIVERSITY MCDUFFIE COUNTY REGIONAL MEDICAL CENTER, INC.'
#  'MILLER FOOT & ANKLE HEALTHCARE INC' 'A. LOUIS JIMENEZ, DPM, PC'
#  'EASTSIDE MEDICAL CENTER, LLC' 'THOMAS J MCELLIGOTT MD PC'
#  'PERIMETER PLASTIC SURGERY'
#  'ATLANTA DERMATOLOGIC SURGERY CONSULTANTS, PC'
#  'RIVERWOODS BEHAVIORAL HEALTH, LLC' 'CHATHAM ORAL SURGERY, PC'
#  'ATLANTIC FOOT AND ANKLE SPECISTS' 'SPORTS MEDICINE SOUTH, LLC'
#  'FAYETTE COMMUNITY HOSPITAL, INC.' 'ATLANTA SPINE INSTITUTE'
#  'NORTHWEST ORAL & MAXILLOFACIAL SURGERY ASSOCIATES, P.C.'
#  'UROLOGY SURGICAL PARTNERS, LLC' 'ROCKDALE MEDICAL CENTER INC.'
#  'THERAPY TRAILS OF EVANS' 'IDEAL THERAPY REHABILITATIVE SERVICES II, LLC'
#  'UNIFIED HEALTHCARE INITIATIVE INC.'
#  'COASTAL VOICE & DYSPHAGIA DIAGNOSTICS, LLC'
#  'EMPOWERME REHABILITATION GEORGIA, LLC' 'THACKER & THOMPSON'
#  'SURGERY SOUTH PC' 'ADVANCED AESTHETICS, P.C' 'BUCKHEAD UROGYNECOLOGY'
#  'MERIDIAN SURGICAL, PC' 'SURGICAL ONCOLOGY OF NORTH GEORGIA, INC.'
#  'GASTROINTESTINAL ENDOSCOPY OF GWINNETT, P.C.'
#  'ARSLANIAN PLASTIC SURGERY PC'
#  'FOOT & ANKLE SPECIALISTS OF NORTHEAST GEORGIA, LLC'
#  'CHEGIREDDY PLASTIC SURGERY, LLC' 'QUINONES & SANCHEZ LLC'
#  'ENT OF ATHENS, LLC' 'LEGACY BRAIN & SPINE LLC' 'ATLANTA BREAST CARE, PC'
#  'RONALD D PATRICK MD LLC' 'BUCKHEAD PLASTIC SURGERY'
#  'AFFILIATED FOOT AND ANKLE, PC' 'CESAR A. GUMUCIO, MD, PC'
#  'REVIVE ORTHOPEDICS SPINE & SPORTS MEDICINE, INC'
#  'THRIVE ORTHOPAEDICS LLC' 'EYE CONSULTANTS OF ATLANTA PIEDMONT'
#  'MSW PODIATRY, PC' 'ANKLE AND FOOT CENTERS INC'
#  'ASSOCIATED FOOT & ANKLE SPECIALISTS, P.C.' 'ATL COLORECTAL SURGERY'
#  'NORTHWEST ENT ASSOCIATES, PC' 'STEPHEN M. BARNETT, MD, PC'
#  'BARIATRIC AND MINIMALLY INVASIVE SURGICAL INSTITUTE'
#  'GEORGIA HAND , SHOULDER AND ELBOW, P.C.'
#  'SURGICAL ASSOICATES OF METRO ATLANTA, LLC'
#  'SURGICAL & COSMETIC DERMATOLOGY, P. C.'
#  'SOUTHERN CROSS SURGERY CENTER, LLC' 'PACES SURGICAL LLCC'
#  'SOUTHERN VEIN CARE' 'SOUTHERN REGIONAL PHYSICIANS MANAGEMENT GROUP, LLC'
#  'ADVANCED CENTER FOR JOINT SURGERY, LLC' 'OPENSIDED MRI OF ATLANTA, LLC'
#  'GEORGIA UROLOGY, PA'
#  'THE HAND AND UPPER EXTREMITY CENTER OF GEORGIA, PC'
#  'THE HAND AND UPPER EXTREMITY SURGERY CENTER OF GEORGIA, LLC'
#  'CARTERSVILLE MEDICAL CENTER LLC' 'CRISP REGIONAL HOSPITAL INC'
#  'SOUTHERN SURGICAL ASSOCIATES, PC' 'ASUCH SURGERY CENTER'
#  'WELLBROOK ENDOSCOPY CENTER, LLC' 'COLUMBUS SURGICAL SPECIALISTS, LLC'
#  'LANE DERMATOLOGY & DERMATOLOGIC SURGERY LLC' 'EDWARD T WILLS DO'
#  'RRSOC LLC' 'JOSEPH BURNETTE, LLC' 'ROSWELL SURGERY CENTER LLC'
#  'ATLANTA SPINE, PC' 'GNS,LLC' 'SURGERY CENTER OF ATHENS LLC'
#  'OPTIMUM SPINE CENTER, LLC' 'THE MEDICAL CENTER INC'
#  'ENT SURGERY CENTER OF ATLANTA,LLC'
#  'AUGUSTA ORTHOPEDIC & SPORTS MEDICINE SPECIALISTS PC'
#  'E PLUS STATESBORO CANCER CARE, LLC' 'MARK SPIVEY ORTHOPEDIC CLINIC, LLC'
#  'EAST GEORGIA CENTER FOR ORAL & FACIAL SURGERY LLC'
#  'PIEDMONT HOSPITAL, INC' 'RIDGEVIEW INSTITUTE,INC'
#  'NORTH GEORGIA FOOT AND ANKLE CLINIC PC'
#  'AMERICAN FOOT & LEG SPECIALISTS, P.C.' 'PREMIER PODIATRY-EAST COBB'
#  'UHS OF PEACHFORD, L.P.' 'SELECT SPECIALTY HOSPITAL - SAVANNAH INC'
#  'PRIME SURGICAL ASSOCIATES INC.'
#  'DEKALB GASTROENTEROLOGY ASSOCIATES III, LLC'
#  "SAINT JOSEPH'S HOSPITAL, INC." 'SELECT SPECIALTY HOSPITAL'
#  'APEX MEDICAL SURGERY CENTER, LLC' 'HHC AUGUSTA, INC'
#  'EAST COAST SURGICAL ASSISTING, LLC'
#  'ADVANCED NEUROSURGICAL SOLUTIONS, LLC' 'SFE ADVANCED MEDICAL CONSULTING'
#  'JAMES B DEPEW MD PC' 'GWINNETT SURGICAL ASSOCIATES, LLP'
#  'NORTHSIDE PLASTIC SURGERY' 'THE PHILIP ISRAEL BREAST CENTER, P.C.'
#  'ENDOSCOPY CONSULTANTS, LLC'
#  'NORTHWEST GEORGIA ORTHOPAEDIC SURGERY CENTER, LLC'
#  'SCHULZE EYE CENTER, P.C.' 'METRO SURGICAL, PC'
#  'PREMIER HEALTHCARE INVESTMENTS'
#  'GEORGIA COLON & RECTALL SURGICAL ASSOCIATES PC'
#  'ADVANCED JOINT SURGERY SPECIALISTS, LLC'
#  'NORTHEAST GEORGIA DIAGNOSTIC ASSOCIATES AND CLINIC, LLC'
#  'SPORTS MEDICINE SOUTH OF GWINNETT LLC' 'SCREVEN COUNTY HOSPITAL, LLC'
#  'MACON ORTHOPAEDIC & HAND CENTER, PA' 'SPECIALTY ORTHOPAEDICS, PC'
#  'GWINNETT SURGERY CENTER, LLC' 'AMERICAN TRANSITIONAL HOSPITALS LLC'
#  'EAST GEORGIA REGIONAL MEDICAL CENTER, LLC'
#  'NORTHWEST ENDOSCOPY CENTER, LLC' 'MOODY SURGICAL ASSOCIATES, LLC'
#  'HUGHSTON CLINIC, P.C.' 'HUGHSTON CLINIC SOUTHEAST PC'
#  'PIEDMONT WALTON HOSPITAL INC' 'EFFINGHAM HOSPITAL, INC.'
#  'PRIME HEALTHCARE FOUNDATION - SOUTHERN REGIONAL, LLC'
#  'AU MEDICAL CENTER, INC'
#  'ROOSEVELT WARM SPRINGS REHABILITATION & SPECIALTY HOSPITALS, INC.'
#  'INTEGRITY FOOT & ANKLE CENTER'
#  'THE NEUROLOGICAL INSTITUTE OF SAVANNAH & CENTER FOR SPINE P C'
#  'ENTI ANESTHESIA, LLC' 'GEORGIA PLASTIC & RECONSTRUCTIVE SURGERY'
#  'ATLANTA VEIN CLINIC, LLC' 'NORTH FULTON GENERAL SURGERY, PC'
#  'DR. STEPHEN QUILL, MD, PC' 'NORTHSIDE ORAL SURGERY CENTER LLC'
#  'ST FRANCIS PHYSICIAN PRACTICES LLC' 'WALKER LAKE PHYSICIAN SERVICES, PC'
#  'SOUTHEAST BRAIN & SPINE SURGERY, P.C.' 'EVANS MEMORIAL HOSPITAL'
#  'COLISEUM SAME DAY SURGERY CENTER LP' 'UHS OF ANCHOR L.P.'
#  'UNIVERSITY HEALTH SERVICES,INC' 'HOSPITAL AUTHORITY OF CANDLER COUNTY'
#  'SAVANNAH MULTISPECIALTY ASSOCIATES, LLC'
#  'HEALTH SERVICES OF CENTRAL GEORGIA' 'MERIWETHER HEALTHCARE, L.L.C.'
#  "ST. MARY'S HOSPITAL, INC." 'BAMP CLINICS GEORGIA, LLC'
#  'ATLANTA OCULOFACIAL PLASTIC SURGEONS PC'
#  'ACSH PRIMARY CARE OF GEORGIA, LLC' 'GA ENDOSCOPY CENTER, LLC'
#  'SPALDING ENDOSCOPY CENTER, LLC' 'DAVID B PHARIS MD PC'
#  'CHATHAM ORTHOPAEDIC ASSOCIATES, PA' 'PIEDMONT HENRY HOSPITAL, INC.'
#  'THE SURGERY CENTER, LLC' 'ARC OF GEORGIA, LLC'
#  'WELLSTAR MCG HEALTH WARM SPRINGS, INC.'
#  'ADVANCED SURGERY CENTER PERIMETER, LLC' 'TATTNALL COMMUNITY HOSPITAL'
#  'KALOS SURGICAL ASSOCIATES LLC' 'HOGAN HEALTHCARE CENTER PC'
#  'STATESBORO NEUROSURGERY, LLC' 'POLARIS SPINE & NEUROSURGERY CENTER PC'
#  'NGMC BARROW LLC' 'SHILOH WOUND CARE PC' 'CANDLER HOSPITAL INCORPORATED'
#  'DIGESTIVE CARE ENDOSCOPY'
#  'ORTHOATLANTA SURGERY CENTER OF FAYETTEVILLE, LLC' 'THERAPY WORKS,P.C.'
#  'PIEDMONT NEWTON HOSPITAL, INC.' 'MACON NORTHSIDE HOSPITAL, LLC'
#  'ROME ORTHOPAEDIC CENTER PC' 'LANIER INTERVENTIONAL PAIN CENTER, LLC'
#  'BURKE HOSPITAL COMPANY' 'WILLINGWAY, INC.'
#  'METRO FOOT AND ANKLE CENTERS, PC' 'CARROLLTON SURGICAL GROUP, P. A.'
#  'ATLANTA ORAL & FACIAL SURGERY LLC'
#  'THE BAXLEY AND APPLING COUNTY HOSPITAL AUTHORITY'
#  'ORAL SURGERY ASSOCIATES & DENTAL IMPLANT CENTER PC'
#  'EMANUEL COUNTY HOSPITAL AUTHORITY'
#  'ATLANTA CENTER FOR BREAST & AESTHETIC SURGERY'
#  'GWINNETT ORAL & MAXILLOFACIAL SURGERY, PC'
#  'RESURGENS SURGERY CENTER LLC' 'SCOTTISH RITE CHILDRENS MEDICAL CTR'
#  'UROLOGY SURGERY CENTER OF SAVANNAH, LLLP'
#  'GEORGIA BARIATRICS & SURGICAL ASSOCIATES, PC'
#  'S.VAL PLASTIC SURGERY P.C.' 'PLASTIC SURGERY ASSOCIATES OF GEORGIA'
#  'GAINESVILLE ENDOSCOPY CENTER, LLC' 'VEST MONROE, LLC'
#  'SOUTHERN BONE & JOINT AMBULATORY SURGICAL CENTER, LLC'
#  'THE MEDICAL CENTER HOSPITAL AUTHORITY'
#  'EAR, NOSE & THROAT PLASTIC SURGERY CENTER' 'DA VINCI FOOT AND ANKLE LLC'
#  'FOOT AND ANKLE RECONSTRUCTION CENTER OF GEORGIA LLC'
#  'ATHENS HOSPITALIST SERVICES PC' 'RHETT K. RAINEY, D. O.'
#  'ATLANTA TOTAL FOOT AND ANKLE CARE' 'JAMES A PARKER MD PC'
#  'ATLANTA AREA ORTHOPEDICS AND REGENERATIVE MEDICINE LLC'
#  'GEORGIA BONE & JOINT SURGEONS, P.C,'
#  'PIEDMONT MOUNTAINSIDE HOSPITAL, INC.' 'MRI IMAGING SPECIALISTS CORP'
#  "PEDIATRIC NEUROSURGERY ASSOC AT CHILDREN'S HEALTHCARE OF ATLANTA LLC"
#  'ARTHUR M. BLANK HOSPITAL, INC.' 'ENDOSCOPY ASC OF MIDDLE GEORGIA LLC'
#  'ATHENA UROLOGY SURGERY CENTER LLC' 'CRAWFORD PLASTIC SURGERY'
#  'LANDMARK HOSPITAL OF ATHENS, LLC'
#  'SOUTHEASTERN REGIONAL MEDICAL CENTER, INC.'
#  'MOST PLASTIC & RECONSTRUCTIVE SURGERY PC'
#  'NOVAMED MANAGEMENT SERVICES LLC' 'GRADY MEMORIAL HOSPITAL CORPORATION'
#  'CHRIS MALONE, MD' 'MIDTOWN SURGICAL SPECIALISTS, PC'
#  'RICHARD E. PAUL DMD PC' 'CHOICE PODIATRY CENTER, INC.']

# %%
print(f"unique states: {kept_df['state'].unique()}")
# Out:
# unique states: ['GA']
